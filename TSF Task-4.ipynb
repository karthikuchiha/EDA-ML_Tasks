# %% [markdown]
# # TSF Task - 4: Exploratory Data Analysis - Terrorism
# ## Aim 1: Try to find out the hot zone of terrorism.
# ## Aim 2: What all security issues and insights you can derive by EDA?

# %% [markdown]
# # Presented By: R Karthik

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Imported all the necessary libraries

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
data = pd.read_csv("C:\globalterrorismdb_0718dist.csv",encoding='latin1')
data.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
# ...

# %% [markdown]
# #### The dataset has been successfully imported

# %%
data.columns.values
# Out:
# array(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region', 'region_txt',
#        'provstate', 'city', 'latitude', 'longitude', 'specificity',
#        'vicinity', 'location', 'summary', 'crit1', 'crit2', 'crit3',
#        'doubtterr', 'alternative', 'alternative_txt', 'multiple',
#        'success', 'suicide', 'attacktype1', 'attacktype1_txt',
#        'attacktype2', 'attacktype2_txt', 'attacktype3', 'attacktype3_txt',
#        'targtype1', 'targtype1_txt', 'targsubtype1', 'targsubtype1_txt',
#        'corp1', 'target1', 'natlty1', 'natlty1_txt', 'targtype2',
#        'targtype2_txt', 'targsubtype2', 'targsubtype2_txt', 'corp2',
#        'target2', 'natlty2', 'natlty2_txt', 'targtype3', 'targtype3_txt',
#        'targsubtype3', 'targsubtype3_txt', 'corp3', 'target3', 'natlty3',
#        'natlty3_txt', 'gname', 'gsubname', 'gname2', 'gsubname2',
# ...

# %% [markdown]
# #### These are the columns of the dataset

# %%
data.rename(columns={'iyear':'Year','imonth':'Month','iday':"day",'gname':'Group','country_txt':'Country','region_txt':'Region','provstate':'State','city':'City','latitude':'latitude',
    'longitude':'longitude','summary':'summary','attacktype1_txt':'Attacktype','targtype1_txt':'Targettype','weaptype1_txt':'Weapon','nkill':'kill',
     'nwound':'Wound'},inplace=True)

# %% [markdown]
# #### Renaming all the columns to give it a better look

# %%
data = data[['Year','Month','day','Country','State','Region','City','latitude','longitude',"Attacktype",'kill',
               'Wound','target1','summary','Group','Targettype','Weapon','motive']]

# %% [markdown]
# #### Arranging all the columns accordingly

# %%
data.head()
# Out:
#    Year  Month  day             Country    State                       Region  \
# 0  1970      7    2  Dominican Republic      NaN  Central America & Caribbean
# 1  1970      0    0              Mexico  Federal                North America
# 2  1970      1    0         Philippines   Tarlac               Southeast Asia
# 3  1970      1    0              Greece   Attica               Western Europe
# 4  1970      1    0               Japan  Fukouka                    East Asia
#
#             City   latitude   longitude                      Attacktype  kill  \
# 0  Santo Domingo  18.456792  -69.951164                   Assassination   1.0
# 1    Mexico city  19.371887  -99.086624     Hostage Taking (Kidnapping)   0.0
# 2        Unknown  15.478598  120.599741                   Assassination   1.0
# 3         Athens  37.997490   23.762728               Bombing/Explosion   NaN
# 4        Fukouka  33.580412  130.396361  Facility/Infrastructure Attack   NaN
#
# ...

# %% [markdown]
# #### This is how the dataset will looks after the change/edit

# %%
data.shape
# Out:
# (181691, 18)

# %% [markdown]
# #### There are 1,81,691 rows and 18 columns

# %%
data.isnull().sum()
# Out:
# Year               0
# Month              0
# day                0
# Country            0
# State            421
# Region             0
# City             434
# latitude        4556
# longitude       4557
# Attacktype         0
# kill           10313
# Wound          16311
# target1          636
# summary        66129
# Group              0
# Targettype         0
# Weapon             0
# motive        131130
# dtype: int64

# %%
data['Wound'] = data['Wound'].fillna(0)
data['kill'] = data['kill'].fillna(0)

# %% [markdown]
# #### Correcting the 'NA' values in the dataset

# %%
data['Casualities'] = data['kill'] + data['Wound']

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Data columns (total 19 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Year         181691 non-null  int64
#  1   Month        181691 non-null  int64
#  2   day          181691 non-null  int64
#  3   Country      181691 non-null  object
#  4   State        181270 non-null  object
#  5   Region       181691 non-null  object
#  6   City         181257 non-null  object
#  7   latitude     177135 non-null  float64
#  8   longitude    177134 non-null  float64
#  9   Attacktype   181691 non-null  object
#  10  kill         181691 non-null  float64
#  11  Wound        181691 non-null  float64
#  12  target1      181055 non-null  object
#  13  summary      115562 non-null  object
#  14  Group        181691 non-null  object
#  15  Targettype   181691 non-null  object
#  16  Weapon       181691 non-null  object
#  17  motive       50561 non-null   object
# ...

# %%
data.describe()
# Out:
#                 Year          Month            day       latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean     2002.638997       6.467277      15.505644      23.498343
# std        13.259430       3.388303       8.814045      18.569242
# min      1970.000000       0.000000       0.000000     -53.154613
# 25%      1991.000000       4.000000       8.000000      11.510046
# 50%      2009.000000       6.000000      15.000000      31.467463
# 75%      2014.000000       9.000000      23.000000      34.685087
# max      2017.000000      12.000000      31.000000      74.633553
#
#           longitude           kill          Wound    Casualities
# count  1.771340e+05  181691.000000  181691.000000  181691.000000
# mean  -4.586957e+02       2.266860       2.883296       5.150156
# std    2.047790e+05      11.227057      34.309747      40.555416
# min   -8.618590e+07       0.000000       0.000000       0.000000
# ...

# %% [markdown]
# #### This is the statistical report

# %% [markdown]
# # Visualization

# %%
year = data['Year'].unique()
years_count = data['Year'].value_counts(dropna = False).sort_index()
plt.figure(figsize = (18,10))
sns.barplot(x = year,
           y = years_count,
           palette = "tab10")
plt.xticks(rotation = 50)
plt.xlabel('Attacking Year',fontsize=20)
plt.ylabel('Number of Attacks Each Year',fontsize=20)
plt.title('Terrorists Attack',fontsize=25,backgroundcolor='lightblue')
plt.show()

# %% [markdown]
# ### If we observe this, we get:
# #### Lowest Number of Attack : 1971 & 1973
# #### Highest Number of Attack : 2014 (16000+)

# %%
pd.crosstab(data.Year, data.Region).plot(kind='line',stacked=False,figsize=(20,10))
plt.title('Region: Terrorist Activities each year ',fontsize=25, backgroundcolor='orange')
plt.ylabel('Number of Attacks',fontsize=20)
plt.xlabel("Year",fontsize=20)
plt.show()

# %% [markdown]
# ### If we study this graph, we get -
# #### Highest terrorism in the regions of : Middle East & North Africa
# #### Lowest terrorism in the regions of : East Asia

# %%
plt.subplots(figsize=(20,10))
sns.barplot(data['Country'].value_counts()[:10].index,data['Country'].value_counts()[:10].values,palette='YlOrBr_r')
plt.title('Top Countries Affected', fontsize=25, backgroundcolor='yellow')
plt.xlabel('Countries', fontsize = 20)
plt.ylabel('Count', fontsize = 20 )
plt.xticks(rotation = 90, fontsize=15)
plt.show()

# %% [markdown]
# ### In this we get -
# #### Most Affected Country - Iraq

# %%
df = data[['Year','kill']].groupby(['Year']).sum()
fig, ax4 = plt.subplots(figsize=(20,10))
df.plot(kind='bar',alpha=0.7,ax=ax4, color='orange')
plt.xticks(rotation = 50)
plt.title("Number of Casualties",fontsize=25, backgroundcolor='yellow')
plt.ylabel("Casualties",fontsize=20)
plt.xlabel('Year',fontsize=20)
top_side = ax4.spines["top"]
top_side.set_visible(False)
right_side = ax4.spines["right"]
right_side.set_visible(False)

# %% [markdown]
# ### If we observe this, we get -
# #### Highest number of casualties were recorded in the year of : 2014
# #### Correspondingly that year also recorded the "Highest Number of Attacks"

# %%
data['City'].value_counts().to_frame().sort_values('City',axis=0,ascending=False).head(10).plot(kind='bar',figsize=(20,10),color='red')
plt.xticks(rotation = 50, fontsize=15)
plt.xlabel("City",fontsize=20)
plt.ylabel("Number of attack",fontsize=20)
plt.title("Top 10 Most Affected Cities",fontsize=25, backgroundcolor='orange')
plt.show()

# %%
data[['Attacktype','Wound']].groupby(["Attacktype"],axis=0).sum().plot(kind='line',figsize=(20,10),color=['red'])
plt.xticks(rotation=50)
plt.title("Number of wounded  ",fontsize=25, backgroundcolor='orange')
plt.ylabel('Number of people',fontsize=20)
plt.xlabel('Attack type',fontsize=20)
plt.show()

# %% [markdown]
# ### We Get -
# #### Most Impactful Attacktype : Bombing/Explosion

# %%
data['Attacktype'].value_counts().plot(kind='bar',figsize=(20,10),color='purple')
plt.xticks(rotation = 50, fontsize=10)
plt.xlabel("Attack Category",fontsize=20)
plt.ylabel("Number of attack",fontsize=20)
plt.title("Means of Attack",fontsize=25, backgroundcolor='yellow')
plt.show()

# %% [markdown]
# ### Here we can see :
# #### Frequently used method  : Bombing/Explosion
# (Correspondingly bombing and explosion causes highest injuries)
# #### Least : Hijacking

# %%
data['Group'].value_counts().to_frame().drop('Unknown').head(10).plot(kind='bar',color='green',figsize=(20,10))
plt.title("Top terrorist groups",fontsize=25, backgroundcolor='yellow')
plt.xlabel("terrorist group name",fontsize=20)
plt.ylabel("Attack number",fontsize=20)
plt.show()

# %% [markdown]
# ### If we study this -
# #### Most active terrorist group is : Taliban

# %%
data[['Group','kill']].groupby(['Group'],axis=0).sum().drop('Unknown').sort_values('kill',ascending=False).head(10).plot(kind='barh',color='lightgreen',figsize=(20,10))
plt.title("Casualties: Top 10 terrorist group",fontsize=30, backgroundcolor='lightblue')
plt.xlabel("Terrorist Group Name",fontsize=20)
plt.ylabel("No of killed people",fontsize=20)
plt.show()

# %% [markdown]
# ### Here we get -
# #### The most notorious terrorist group : Islamic State of Iraq and the Levent (ISIL)

# %%
df=data[['Group','Country','kill']]
df=df.groupby(['Group','Country'],axis=0).sum().sort_values('kill',ascending=False).drop('Unknown').reset_index().head(10)
df
# Out:
#                                               Group      Country     kill
# 0       Islamic State of Iraq and the Levant (ISIL)         Iraq  31058.0
# 1                                           Taliban  Afghanistan  29269.0
# 2                                        Boko Haram      Nigeria  16917.0
# 3                                 Shining Path (SL)         Peru  11595.0
# 4           Liberation Tigers of Tamil Eelam (LTTE)    Sri Lanka  10928.0
# 5                                        Al-Shabaab      Somalia   8176.0
# 6  Farabundo Marti National Liberation Front (FMLN)  El Salvador   8019.0
# 7       Islamic State of Iraq and the Levant (ISIL)        Syria   6883.0
# 8                 Nicaraguan Democratic Force (FDN)    Nicaragua   6630.0
# 9                   Tehrik-i-Taliban Pakistan (TTP)     Pakistan   6014.0

# %% [markdown]
# ### Solution 1: The Hot Zones of Terrorism
# #### So as we saw earlier through the graphical representations, the hot zones are around "Middle east and nothern Africa" followed by "South Asia"

# %% [markdown]
# ### Solution 2:  What all security issues and insights you can derive by EDA?
# #### If we study this dataset we can observe the fact that most of the attacks are made through "Bombings and Explosion", Therfore, all the nations should enhance or upgrade thier bomb detecting and disposal techniques and technologies
# #### We saw that Taliban and ISIL group contribute to the majority of the attacks made, so an Anti Terrorism Group should be formed with the help of all the nations to eradicate these kind of terrorists group

# %% [markdown]
# # Thank You!!
